# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_csv("data/2d-dataset4.csv")
# data = data[data["y"] == 1]
label = data["y"].to_numpy()
x = data["alpha"].to_numpy()
y = data["beta"].to_numpy()
plt.scatter(x,y)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
# algorithm
k = 2 # hyperparameter we could iterate through

# steps:
# 1. set k
# 2. initialise k points randomly as cluster centres
# 3. assign each data point to the closest cluster
# 4. compute centroid for each cluster
# 5. centroid is new cluster centre
# 6. jump to step 3 if not converged

# %%
points = [[x[i], y[i]] for i in range(len(x))]
print(len(points))
# Out:
# 676
